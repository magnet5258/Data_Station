# %%
import pandas as pd

# %%
df1 = pd.read_csv('preprocessing_data.csv')
df1.head()
# Out:
#    Unnamed: 0  Ox_Chamber    process type    Temp_OXid Vapor    ppm  Pressure  \
# 0           0           1  Oxidation  dry  1138.979159    O2  32.80     0.200
# 1           1           1  Oxidation  dry  1218.184551    O2  31.86     0.194
# 2           2           1  Oxidation  dry  1062.467808    O2  39.51     0.217
# 3           3           1  Oxidation  dry  1114.704773    O2  32.88     0.201
# 4           4           1  Oxidation  dry   989.411946    O2  38.11     0.204
#
#    Oxid_time  thickness  ...      Flux480s      Flux840s  input_Energy  \
# 0       62.0    699.443  ...  3.002593e+17  6.000007e+17     31574.410
# 1      137.0    696.792  ...  3.017903e+17  6.000012e+17     31580.213
# 2      128.0    705.471  ...  2.994231e+17  6.000002e+17     32162.414
# 3       90.0    710.772  ...  2.991354e+17  6.000003e+17     32874.925
# 4       98.0    716.975  ...  3.005576e+17  6.000013e+17     30985.928
#
#    Temp_implantation Furance_Temp  RTA_Temp  Target  Error_message  \
# 0            102.847        885.0       154      96           none
# 1            104.323        919.0       154     102           none
# 2            100.605        916.0       155      95           none
# 3            101.739        911.0       156     117           none
# 4            106.422        872.0       155     143           none
#
#    target_binom  Chamber_Route
# 0           0.0    route_11133
# 1           0.0    route_11222
# 2           0.0    route_11311
# 3           0.0    route_12111
# 4           0.0    route_12222
#
# [5 rows x 60 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 752 entries, 0 to 751
# Data columns (total 60 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           752 non-null    int64
#  1   Ox_Chamber           752 non-null    int64
#  2   process              752 non-null    object
#  3   type                 752 non-null    object
#  4   Temp_OXid            752 non-null    float64
#  5   Vapor                752 non-null    object
#  6   ppm                  752 non-null    float64
#  7   Pressure             752 non-null    float64
#  8   Oxid_time            752 non-null    float64
#  9   thickness            752 non-null    float64
#  10  No_Die               752 non-null    object
#  11  Reinforcement        752 non-null    bool
#  12  Unnamed: 0_x         752 non-null    int64
#  13  photo_soft_Chamber   752 non-null    int64
#  14  process 2            752 non-null    object
#  15  resist_target        752 non-null    float64
#  16  N2_HMDS              752 non-null    float64
#  17  pressure_HMDS        752 non-null    float64
#  18  temp_HMDS            752 non-null    float64
#  19  temp_HMDS_bake       752 non-null    float64
#  20  time_HMDS_bake       752 non-null    float64
#  21  spin1                752 non-null    float64
#  22  spin2                752 non-null    float64
#  23  spin3                752 non-null    float64
#  24  photoresist_bake     752 non-null    float64
#  25  temp_softbake        752 non-null    float64
#  26  time_softbake        752 non-null    float64
#  27  lithography_Chamber  752 non-null    int64
#  28  Line_CD              752 non-null    float64
#  29  UV_type              752 non-null    object
#  30  Wavelength           752 non-null    int64
#  31  Resolution           752 non-null    float64
#  32  Energy_Exposure      752 non-null    float64
#  33  Range_check          752 non-null    bool
#  34  Unnamed: 0_y         752 non-null    int64
#  35  Etching_Chamber      752 non-null    int64
#  36  Process 3            752 non-null    object
#  37  Temp_Etching         752 non-null    float64
#  38  Source_Power         752 non-null    float64
#  39  Selectivity          752 non-null    float64
#  40  Thin Film 4          752 non-null    float64
#  41  Thin Film 3          752 non-null    float64
#  42  Thin Film 2          752 non-null    float64
#  43  Thin Film 1          752 non-null    float64
#  44  Etching_rate         752 non-null    float64
#  45  Chamber_Num          752 non-null    int64
#  46  process4             752 non-null    object
#  47  Flux60s              752 non-null    float64
#  48  Flux90s              752 non-null    float64
#  49  Flux160s             752 non-null    float64
#  50  Flux480s             752 non-null    float64
#  51  Flux840s             752 non-null    float64
#  52  input_Energy         752 non-null    float64
#  53  Temp_implantation    752 non-null    float64
#  54  Furance_Temp         752 non-null    float64
#  55  RTA_Temp             752 non-null    int64
#  56  Target               752 non-null    int64
#  57  Error_message        752 non-null    object
#  58  target_binom         752 non-null    float64
#  59  Chamber_Route        752 non-null    object
# dtypes: bool(2), float64(37), int64(11), object(10)
# memory usage: 342.3+ KB

# %%
Y = df1['Target'] # Wafer 내 불량 Chip 개수
X = df1[['Temp_OXid', 'Oxid_time', 'thickness', 'Line_CD',
         'Etching_rate', 'Temp_Etching']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 1234)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (564, 6)
# (188, 6)
# (564,)
# (188,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

# %%
r2_score(Y_train, Y_train_pred)
# Out:
# 0.34582379022991816

# %%
r2_score(Y_test, Y_test_pred)
# Out:
# 0.29396801142541706

# %%
mean_squared_error(Y_train, Y_train_pred)
# Out:
# np.float64(2684.9553213362337)

# %%
mean_squared_error(Y_test, Y_test_pred)
# Out:
# np.float64(2089.478577922479)

# %%
def evaluation_reg(model):
    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)
    print("학습 데이터 결정계수 :", r2_score(Y_train, Y_train_pred))
    print("검증 데이터 결정계수 :", r2_score(Y_test, Y_test_pred))
    print("학습 데이터 MSE :", mean_squared_error(Y_train, Y_train_pred))
    print("검증 데이터 MSE :", mean_squared_error(Y_test, Y_test_pred))
    print("학습 데이터 MAE :", mean_absolute_error(Y_train, Y_train_pred))
    print("검증 데이터 MAE :", mean_absolute_error(Y_test, Y_test_pred))

# %%
evaluation_reg(model)
# Out:
# 학습 데이터 결정계수 : 0.34582379022991816
# 검증 데이터 결정계수 : 0.29396801142541706
# 학습 데이터 MSE : 2684.9553213362337
# 검증 데이터 MSE : 2089.478577922479
# 학습 데이터 MAE : 37.2300116180249
# 검증 데이터 MAE : 34.71724975119037

# %% [markdown]
# # 특성공학 기법 적용
# - Pipe Line : 학습과 특성공학 기법을 동시에 사용하여 데이터를 한꺼번에 처리하면서 학습을 수행하는 함수

# %%
from sklearn.pipeline import Pipeline # 학습 + 특성공학
from sklearn.impute import SimpleImputer # 결측값 처리 함수

# %%
pipe_list = [('imputer', SimpleImputer()),
             ('model', LinearRegression())]
pipe_model = Pipeline(pipe_list)
pipe_model
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('model', LinearRegression())])

# %%
pipe_model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('model', LinearRegression())])

# %%
evaluation_reg(pipe_model)
# Out:
# 학습 데이터 결정계수 : 0.34582379022991816
# 검증 데이터 결정계수 : 0.29396801142541706
# 학습 데이터 MSE : 2684.9553213362337
# 검증 데이터 MSE : 2089.478577922479
# 학습 데이터 MAE : 37.2300116180249
# 검증 데이터 MAE : 34.71724975119037

# %% [markdown]
# **새로운 값을 직접 입력하여 예측**

# %%
X
# Out:
#        Temp_OXid  Oxid_time  thickness  Line_CD  Etching_rate  Temp_Etching
# 0    1138.979159       62.0    699.443   30.959       2.75950        70.878
# 1    1218.184551      137.0    696.792   29.653       2.72775        69.561
# 2    1062.467808      128.0    705.471   28.063       2.67000        70.968
# 3    1114.704773       90.0    710.772   31.556       2.74825        70.146
# 4     989.411946       98.0    716.975   31.969       2.74625        71.174
# ..           ...        ...        ...      ...           ...           ...
# 747  1280.687973       21.0    708.586   35.404       2.67450        70.859
# 748  1275.153349       22.0    712.936   31.011       2.72725        71.294
# 749  1275.182502       21.0    715.498   32.525       2.72275        71.550
# 750  1268.105427       22.0    707.179   28.001       2.69150        70.718
# 751  1278.097085       22.0    716.238   30.007       2.70525        71.624
#
# [752 rows x 6 columns]

# %%
x1 = input('Temp_Oxid을 입력하시오 : ')
x2 = input('Oxid_time을 입력하시오 : ')
x3 = input('thickness를 입력하시오 : ')
x4 = input('Line_CD를 입력하시오 : ')
x5 = input('Etching_rate를 입력하시오 : ')
x6 = input('Temp_Etching을 입력하시오 : ')
# Out:
# Temp_Oxid을 입력하시오 :  100
# Oxid_time을 입력하시오 :  200
# thickness를 입력하시오 :  50
# Line_CD를 입력하시오 :  50
# Etching_rate를 입력하시오 :  30
# Temp_Etching을 입력하시오 :  40

# %%
input_new_data = pd.DataFrame([[x1, x2, x3, x4, x5, x6]], columns = X.columns.tolist())

# %%
pipe_model.predict(input_new_data)
# Out:
# array([32248.38608327])

# %% [markdown]
# **결측값이 있어도, Pipe Line 함수로 인해 오류 없이 예측값이 계산되어 출력**

# %%
import numpy as np

# %%
input_new_data2 = pd.DataFrame([[x1, np.nan, x3, x4, x5, x6]], columns = X.columns.tolist())
input_new_data2
# Out:
#   Temp_OXid  Oxid_time thickness Line_CD Etching_rate Temp_Etching
# 0       100        NaN        50      50           30           40

# %%
pipe_model.predict(input_new_data2)
# Out:
# array([32241.76629099])

# %% [markdown]
# **Scaling & Encoding**
# - Scaling -> 연속형
# - Encoding -> 범주형
# - Imputation -> 연속 / 범주

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Ox_Chamber', 'process', 'type', 'Temp_OXid', 'Vapor',
#        'ppm', 'Pressure', 'Oxid_time', 'thickness', 'No_Die', 'Reinforcement',
#        'Unnamed: 0_x', 'photo_soft_Chamber', 'process 2', 'resist_target',
#        'N2_HMDS', 'pressure_HMDS', 'temp_HMDS', 'temp_HMDS_bake',
#        'time_HMDS_bake', 'spin1', 'spin2', 'spin3', 'photoresist_bake',
#        'temp_softbake', 'time_softbake', 'lithography_Chamber', 'Line_CD',
#        'UV_type', 'Wavelength', 'Resolution', 'Energy_Exposure', 'Range_check',
#        'Unnamed: 0_y', 'Etching_Chamber', 'Process 3', 'Temp_Etching',
#        'Source_Power', 'Selectivity', 'Thin Film 4', 'Thin Film 3',
#        'Thin Film 2', 'Thin Film 1', 'Etching_rate', 'Chamber_Num', 'process4',
#        'Flux60s', 'Flux90s', 'Flux160s', 'Flux480s', 'Flux840s',
#        'input_Energy', 'Temp_implantation', 'Furance_Temp', 'RTA_Temp',
#        'Target', 'Error_message', 'target_binom', 'Chamber_Route'],
#       dtype='object')

# %%
Y = df1['Target']
X = df1[['Oxid_time', 'thickness', 'Vapor', 'resist_target', 'Line_CD',
         'Etching_rate', 'UV_type']]

# %%
X
# Out:
#      Oxid_time  thickness Vapor  resist_target  Line_CD  Etching_rate UV_type
# 0         62.0    699.443    O2       1.211940   30.959       2.75950       H
# 1        137.0    696.792    O2       0.887720   29.653       2.72775       H
# 2        128.0    705.471    O2       1.113156   28.063       2.67000       I
# 3         90.0    710.772    O2       0.882195   31.556       2.74825       I
# 4         98.0    716.975    O2       0.834001   31.969       2.74625       I
# ..         ...        ...   ...            ...      ...           ...     ...
# 747       21.0    708.586   H2O       0.923802   35.404       2.67450       I
# 748       22.0    712.936   H2O       0.837348   31.011       2.72725       I
# 749       21.0    715.498   H2O       0.859869   32.525       2.72275       I
# 750       22.0    707.179   H2O       0.914315   28.001       2.69150       I
# 751       22.0    716.238   H2O       0.938200   30.007       2.70525       I
#
# [752 rows x 7 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 1234)

# %%
# 문자데이터와 숫자데이터를 구분하여 처리하는 프로세스를 구축할 때 사용하는 함수
from sklearn.compose import make_column_transformer
# 특성공학 + 학습
from sklearn.pipeline import make_pipeline
# Scaling & Encoding
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

# %%
# 연속형 데이터 이름을 리스트로 선언
numeric_list = ['Oxid_time', 'thickness', 'resist_target', 'Line_CD', 'Etching_rate']
category_list = ['Vapor', 'UV_type']

# %%
# 연속형 데이터가 처리되는 Process
# 결측값을 평균으로 대치한 다음, Scale을 최소 0 / 최대 1로 변환
numeric_pipe = make_pipeline(SimpleImputer(strategy = 'mean'), MinMaxScaler())
numeric_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('minmaxscaler', MinMaxScaler())])

# %%
# 범주형 데이터가 처리되는 Process
# 결측값을 최빈값으로 대치한 다음, 문자데이터를 OneHot 인코딩 변환
category_pipe = make_pipeline(SimpleImputer(strategy = 'most_frequent'), OneHotEncoder())
category_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder', OneHotEncoder())])

# %%
# 연속형과 범주형을 나누어 처리하는 Pipe를 구성
preprocessing_pipe = make_column_transformer((numeric_pipe, numeric_list),
                                             (category_pipe, category_list))
preprocessing_pipe
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler())]),
#                                  ['Oxid_time', 'thickness', 'resist_target',
#                                   'Line_CD', 'Etching_rate']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder())]),
#                                  ['Vapor', 'UV_type'])])

# %%
pipe_model = make_pipeline(preprocessing_pipe, LinearRegression())
pipe_model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Oxid_time', 'thickness',
#                                                    'resist_target', 'Line_CD',
#                                                    'Etching_rate']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Vapor', 'UV_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
pipe_model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Oxid_time', 'thickness',
#                                                    'resist_target', 'Line_CD',
#                                                    'Etching_rate']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Vapor', 'UV_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
evaluation_reg(pipe_model)
# Out:
# 학습 데이터 결정계수 : 0.3804084568229765
# 검증 데이터 결정계수 : 0.2871965092882167
# 학습 데이터 MSE : 2543.0084219858154
# 검증 데이터 MSE : 2109.5186170212764
# 학습 데이터 MAE : 36.37145390070922
# 검증 데이터 MAE : 35.170212765957444

# %% [markdown]
# **교차 검증 Cross Validation (CV)**

# %%
from sklearn.model_selection import GridSearchCV

# %%
# 5회의 교차검증을 실시하며 학습을 수행 (Pipe Model의 Process를 따라가며 학습)
grid_model = GridSearchCV(pipe_model, param_grid = {}, cv = 5)
grid_model.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('minmaxscaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Oxid_time',
#                                                                           'thickness',
#                                                                           'resist_target',
#                                                                           'Line_CD',
#                                                                           'Etching_rate']),
#                                                                         ('pipeline-2',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehotencoder',
#                                                                                           OneHotEncoder())]),
#                                                                          ['Vapor',
#                                                                           'UV_type'])])),
#                                        ('linearregression',
#                                         LinearRegression())]),
#              param_grid={})

# %%
# 교차검증 이후 가장 성능이 좋은 Model 선택
best_model = grid_model.best_estimator_

# %%
evaluation_reg(best_model)
# Out:
# 학습 데이터 결정계수 : 0.3804084568229765
# 검증 데이터 결정계수 : 0.2871965092882167
# 학습 데이터 MSE : 2543.0084219858154
# 검증 데이터 MSE : 2109.5186170212764
# 학습 데이터 MAE : 36.37145390070922
# 검증 데이터 MAE : 35.170212765957444

# %% [markdown]
# **Hyper Parameter Tuning**

# %%
# 의사결정나무 알고리즘
from sklearn.tree import DecisionTreeRegressor

# %%
# 연속형과 범주형을 나누어 처리하는 Pipe를 구성
preprocessing_pipe = make_column_transformer((numeric_pipe, numeric_list),
                                             (category_pipe, category_list))
pipe_model = make_pipeline(preprocessing_pipe, DecisionTreeRegressor())

# %%
# depth : 5 ~ 10 6개 / split : 1 ~ 10 10개 / leaf : 5 ~ 10 6개 -> 360가지 경우의 수
hyperparameter = {'decisiontreeregressor__max_depth' : range(5, 11),
                 'decisiontreeregressor__min_samples_split' : range(1, 11),
                 'decisiontreeregressor__min_samples_leaf' : range(5, 11)}

grid_model = GridSearchCV(pipe_model, param_grid = hyperparameter, cv = 5)
grid_model.fit(X_train, Y_train)
# Out:
# C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 180 fits failed out of a total of 1800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# C:\Users\magne\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan 0.28114358 0.28114358 0.28114358 0.28114358 0.28114358
#  0.28114358 0.28114358 0.28114358 0.28114358        nan 0.26927114
#  0.26927114 0.26927114 0.26927114 0.26927114 0.26927114 0.26927114
#  0.26927114 0.26927114        nan 0.26446005 0.26446005 0.26446005
#  0.26446005 0.26446005 0.26446005 0.26446005 0.26446005 0.26446005
#         nan 0.25964486 0.25964486 0.25964486 0.25964486 0.25964486
#  0.25964486 0.25964486 0.25964486 0.25964486        nan 0.25584335
#  0.25584335 0.25584335 0.25584335 0.25584335 0.25584335 0.25584335
#  0.25584335 0.25584335        nan 0.26299308 0.26299308 0.26299308
#  0.26299308 0.26299308 0.26299308 0.26299308 0.26299308 0.26299308
#         nan 0.25375979 0.25375979 0.25375979 0.25375979 0.25375979
#  0.25375979 0.25375979 0.25375979 0.25375979        nan 0.24785455
#  0.24785455 0.24785455 0.24785455 0.24785455 0.24785455 0.24785455
#  0.24785455 0.24785455        nan 0.23865649 0.23922094 0.23865649
#  0.23649176 0.23705621 0.23865649 0.23705621 0.23922094 0.23705621
#         nan 0.24454944 0.2451139  0.24454944 0.2451139  0.2451139
#  0.2451139  0.2451139  0.2451139  0.2451139         nan 0.25098883
#  0.25155328 0.25155328 0.25155328 0.25098883 0.25098883 0.25155328
#  0.25098883 0.25155328        nan 0.24940837 0.24940837 0.24997282
#  0.24997282 0.24997282 0.24997282 0.24997282 0.24940837 0.24997282
#         nan 0.21704038 0.2214879  0.2214879  0.2214879  0.2214879
#  0.21704038 0.2214879  0.21704038 0.21704038        nan 0.21113122
#  0.21113122 0.2066837  0.2066837  0.21113122 0.21113122 0.21113122
#  0.2066837  0.21113122        nan 0.2174179  0.21690355 0.21747937
#  0.21809816 0.21622078 0.21822361 0.21890388 0.21884241 0.21615931
#         nan 0.22343093 0.22343093 0.22409232 0.22409232 0.22343093
#  0.22409232 0.22409232 0.22409232 0.22409232        nan 0.22991776
#  0.22991776 0.22928576 0.22991776 0.22991776 0.22991776 0.22991776
#  0.22928576 0.22991776        nan 0.22369315 0.22432515 0.22369315
#  0.22369315 0.22369315 0.22369315 0.22369315 0.22369315 0.22369315
#         nan 0.16620289 0.16941503 0.17386256 0.16941503 0.17065041
#  0.16941503 0.17386256 0.16941503 0.16620289        nan 0.18480704
#  0.18925457 0.18925457 0.18480704 0.18480704 0.18480704 0.18480704
#  0.18480704 0.18925457        nan 0.20697972 0.20615935 0.20697972
#  0.20809821 0.20697972 0.20747942 0.20622083 0.20697972 0.20622083
#         nan 0.22648767 0.22650016 0.22650016 0.22650016 0.22648767
#  0.22648767 0.22650016 0.22650016 0.22650016        nan 0.23607878
#  0.23671078 0.23671078 0.23607878 0.23607878 0.23607878 0.23671078
#  0.23607878 0.23671078        nan 0.22122764 0.22059564 0.22059564
#  0.22059564 0.22122764 0.22122764 0.22122764 0.22122764 0.22059564
#         nan 0.15534266 0.15979019 0.15213052 0.15657804 0.15534266
#  0.15534266 0.15979019 0.15213052 0.15657804        nan 0.17744947
#  0.18189699 0.18189699 0.18189699 0.17744947 0.17744947 0.17744947
#  0.18189699 0.17744947        nan 0.20224641 0.20224641 0.20154899
#  0.20280758 0.20348784 0.20224641 0.20348784 0.20230789 0.20424674
#         nan 0.22264023 0.22264023 0.22264023 0.22265272 0.22264023
#  0.22265272 0.22264023 0.22265272 0.22265272        nan 0.24043958
#  0.24043958 0.24107158 0.24043958 0.24043958 0.24107158 0.24107158
#  0.24043958 0.24107158        nan 0.22233143 0.22296343 0.22296343
#  0.22233143 0.22233143 0.22296343 0.22296343 0.22296343 0.22296343
#         nan 0.14343628 0.1477855  0.14343628 0.14333797 0.14664842
#  0.14664842 0.14343628 0.1477855  0.1478838         nan 0.17688013
#  0.17688013 0.1724326  0.17688013 0.1724326  0.1724326  0.1724326
#  0.17688013 0.1724326         nan 0.19551296 0.19557443 0.19683302
#  0.19683302 0.19683302 0.19601265 0.19481554 0.19601265 0.19745181
#         nan 0.21729247 0.21730497 0.21729247 0.21729247 0.21729247
#  0.21730497 0.21730497 0.21730497 0.21730497        nan 0.23851424
#  0.23851424 0.23851424 0.23788224 0.23788224 0.23788224 0.23851424
#  0.23851424 0.23788224        nan 0.22231953 0.22231953 0.22231953
#  0.22168753 0.22231953 0.22168753 0.22231953 0.22168753 0.22231953]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('minmaxscaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Oxid_time',
#                                                                           'thickness',
#                                                                           'resist_target',
#                                                                           'Line_CD',
#                                                                           'Etching_rate']),
#                                                                         ('pipeline-2',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehotencoder',
#                                                                                           OneHotEncoder())]),
#                                                                          ['Vapor',
#                                                                           'UV_type'])])),
#                                        ('decisiontreeregressor',
#                                         DecisionTreeRegressor())]),
#              param_grid={'decisiontreeregressor__max_depth': range(5, 11),
#                          'decisiontreeregressor__min_samples_leaf': range(5, 11),
#                          'decisiontreeregressor__min_samples_split': range(1, 11)})

# %%
# 가장 적절한 모델을 선택
best_model = grid_model.best_estimator_
best_model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Oxid_time', 'thickness',
#                                                    'resist_target', 'Line_CD',
#                                                    'Etching_rate']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Vapor', 'UV_type'])])),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=5, min_samples_leaf=5))])

# %%
evaluation_reg(best_model)
# Out:
# 학습 데이터 결정계수 : 0.6071143811638606
# 검증 데이터 결정계수 : -0.14097311763387732
# 학습 데이터 MSE : 1612.532399093697
# 검증 데이터 MSE : 3376.6726237072885
# 학습 데이터 MAE : 30.07200540661487
# 검증 데이터 MAE : 40.95643622461593
